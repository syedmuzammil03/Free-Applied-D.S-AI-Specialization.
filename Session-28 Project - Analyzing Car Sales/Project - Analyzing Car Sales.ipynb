# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cars = pd.read_csv("cars.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
# ...

# %%
cars = pd.read_csv("cars.csv", encoding = "latin-1")

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
cars.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
cars["brand"]
# Out:
# 0           peugeot
# 1               bmw
# 2        volkswagen
# 3             smart
# 4              ford
#             ...
# 49995          audi
# 49996          opel
# 49997          fiat
# 49998          audi
# 49999          opel
# Name: brand, Length: 50000, dtype: object

# %%
cars["brand"].value_counts()
# Out:
# brand
# volkswagen        10687
# opel               5461
# bmw                5429
# mercedes_benz      4734
# audi               4283
# ford               3479
# renault            2404
# peugeot            1456
# fiat               1308
# seat                941
# skoda               786
# mazda               757
# nissan              754
# smart               701
# citroen             701
# toyota              617
# sonstige_autos      546
# hyundai             488
# volvo               457
# mini                424
# mitsubishi          406
# honda               399
# kia                 356
# alfa_romeo          329
# porsche             294
# suzuki              293
# chevrolet           283
# chrysler            181
# dacia               129
# daihatsu            128
# jeep                110
# subaru              109
# land_rover           99
# saab                 80
# daewoo               79
# trabant              78
# jaguar               77
# rover                69
# ...

# %%
cars["brand"].value_counts(normalize = True)
# Out:
# brand
# volkswagen        0.21374
# opel              0.10922
# bmw               0.10858
# mercedes_benz     0.09468
# audi              0.08566
# ford              0.06958
# renault           0.04808
# peugeot           0.02912
# fiat              0.02616
# seat              0.01882
# skoda             0.01572
# mazda             0.01514
# nissan            0.01508
# smart             0.01402
# citroen           0.01402
# toyota            0.01234
# sonstige_autos    0.01092
# hyundai           0.00976
# volvo             0.00914
# mini              0.00848
# mitsubishi        0.00812
# honda             0.00798
# kia               0.00712
# alfa_romeo        0.00658
# porsche           0.00588
# suzuki            0.00586
# chevrolet         0.00566
# chrysler          0.00362
# dacia             0.00258
# daihatsu          0.00256
# jeep              0.00220
# subaru            0.00218
# land_rover        0.00198
# saab              0.00160
# daewoo            0.00158
# ...

# %%
selling_prop = cars["brand"].value_counts(normalize = True)
selling_prop
# Out:
# brand
# volkswagen        0.21374
# opel              0.10922
# bmw               0.10858
# mercedes_benz     0.09468
# audi              0.08566
# ford              0.06958
# renault           0.04808
# peugeot           0.02912
# fiat              0.02616
# seat              0.01882
# skoda             0.01572
# mazda             0.01514
# nissan            0.01508
# smart             0.01402
# citroen           0.01402
# toyota            0.01234
# sonstige_autos    0.01092
# hyundai           0.00976
# volvo             0.00914
# mini              0.00848
# mitsubishi        0.00812
# honda             0.00798
# kia               0.00712
# alfa_romeo        0.00658
# porsche           0.00588
# suzuki            0.00586
# chevrolet         0.00566
# chrysler          0.00362
# dacia             0.00258
# daihatsu          0.00256
# jeep              0.00220
# subaru            0.00218
# land_rover        0.00198
# saab              0.00160
# daewoo            0.00158
# ...

# %%
selling_bol = selling_prop > 0.05
selling_bol
# Out:
# brand
# volkswagen         True
# opel               True
# bmw                True
# mercedes_benz      True
# audi               True
# ford               True
# renault           False
# peugeot           False
# fiat              False
# seat              False
# skoda             False
# mazda             False
# nissan            False
# smart             False
# citroen           False
# toyota            False
# sonstige_autos    False
# hyundai           False
# volvo             False
# mini              False
# mitsubishi        False
# honda             False
# kia               False
# alfa_romeo        False
# porsche           False
# suzuki            False
# chevrolet         False
# chrysler          False
# dacia             False
# daihatsu          False
# jeep              False
# subaru            False
# land_rover        False
# saab              False
# daewoo            False
# trabant           False
# jaguar            False
# rover             False
# ...

# %%
top_brand = selling_prop[selling_bol]
top_brand
# Out:
# brand
# volkswagen       0.21374
# opel             0.10922
# bmw              0.10858
# mercedes_benz    0.09468
# audi             0.08566
# ford             0.06958
# Name: proportion, dtype: float64

# %%
top_brand.values
# Out:
# array([0.21374, 0.10922, 0.10858, 0.09468, 0.08566, 0.06958])

# %%
brand_name = top_brand.index
brand_name
# Out:
# Index(['volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford'], dtype='object', name='brand')

# %%
cars
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
brand_bol = cars["brand"].isin(brand_name)
brand_bol
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 49995     True
# 49996     True
# 49997    False
# 49998     True
# 49999     True
# Name: brand, Length: 50000, dtype: bool

# %%
top_selling_brand = cars[brand_bol].copy()

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand["price"]
# Out:
# 1         $8,500
# 2         $8,990
# 4         $1,350
# 6           $300
# 7         $1,990
#           ...
# 49994     $5,000
# 49995    $24,900
# 49996     $1,980
# 49998    $22,900
# 49999     $1,250
# Name: price, Length: 34073, dtype: object

# %%
top_selling_brand["price"].str.replace("$", "").str.replace(",","").astype(int)
# Out:
# 1         8500
# 2         8990
# 4         1350
# 6          300
# 7         1990
#          ...
# 49994     5000
# 49995    24900
# 49996     1980
# 49998    22900
# 49999     1250
# Name: price, Length: 34073, dtype: int32

# %%
top_selling_brand["price"] = top_selling_brand["price"].str.replace("$", "").str.replace(",","").astype(int)

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand["odometer"].str.replace("km","").str.replace(",","").astype(int)
# Out:
# 1        150000
# 2         70000
# 4        150000
# 6        150000
# 7        150000
#           ...
# 49994    150000
# 49995    100000
# 49996    150000
# 49998     40000
# 49999    150000
# Name: odometer, Length: 34073, dtype: int32

# %%
top_selling_brand["odometer"] = top_selling_brand["odometer"].str.replace("km","").str.replace(",","").astype(int)

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand.rename({"price":"price ($)", "odometer":"odometer (km)"}, axis = 1)
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand.rename({"price":"price ($)", "odometer":"odometer (km)"}, axis = 1, inplace = True)

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
groupping = top_selling_brand.groupby("brand")

# %%
brand_mean = groupping[["price ($)", "odometer (km)"]].mean()
brand_mean
# Out:
#                   price ($)  odometer (km)
# brand
# audi            8965.560355  129643.941163
# bmw             8252.918954  132521.643028
# ford            7105.662547  124131.934464
# mercedes_benz  29511.955429  130886.142797
# opel            5106.092657  129298.663248
# volkswagen      6384.167400  128955.272761

# %%
brand_mean.sort_values("price ($)", ascending = False)
# Out:
#                   price ($)  odometer (km)
# brand
# mercedes_benz  29511.955429  130886.142797
# audi            8965.560355  129643.941163
# bmw             8252.918954  132521.643028
# ford            7105.662547  124131.934464
# volkswagen      6384.167400  128955.272761
# opel            5106.092657  129298.663248

# %%
top_selling_brand["price ($)"].value_counts().sort_index()
# Out:
# price ($)
# 0           976
# 1           112
# 2             1
# 3             1
# 5             2
#            ...
# 999999        2
# 1234566       1
# 11111111      2
# 12345678      1
# 99999999      1
# Name: count, Length: 2000, dtype: int64

# %%
normal_price_bol = top_selling_brand["price ($)"].between(1,351000)
normal_price_bol
# Out:
# 1        True
# 2        True
# 4        True
# 6        True
# 7        True
#          ...
# 49994    True
# 49995    True
# 49996    True
# 49998    True
# 49999    True
# Name: price ($), Length: 34073, dtype: bool

# %%
normal_data = top_selling_brand[normal_price_bol ]

# %%
normal_data["price ($)"].value_counts().sort_index()
# Out:
# price ($)
# 1         112
# 2           1
# 3           1
# 5           2
# 10          4
#          ...
# 175000      1
# 180000      1
# 190000      1
# 250000      1
# 259000      1
# Name: count, Length: 1993, dtype: int64

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand["yearOfRegistration"].value_counts().sort_index() # 2016
# Out:
# yearOfRegistration
# 1000    1
# 1910    2
# 1927    1
# 1929    1
# 1931    1
#        ..
# 5000    2
# 5911    1
# 6200    1
# 9000    1
# 9999    4
# Name: count, Length: 79, dtype: int64
