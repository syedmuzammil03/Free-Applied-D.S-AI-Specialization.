# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

# %%
import requests

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
html_txt = response.text # html format

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_txt , "html.parser")

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
table = soup.find("table", {"class":"wikitable"})

# %%
table
# Out:
# <table class="wikitable sortable sticky-header col2left col6left" style="text-align:right">
# <tbody><tr>
# <th>
# </th>
# <th style="width:17em"><a href="/wiki/List_of_sovereign_states" title="List of sovereign states">Country</a> / <a href="/wiki/Dependent_territory" title="Dependent territory">dependency</a>
# </th>
# <th>Population
# </th>
# <th style="width:2em">% of<br/>world
# </th>
# <th>Date
# </th>
# <th><span class="nowrap">Source (official or from</span><br/>the <a href="/wiki/United_Nations" title="United Nations">United Nations</a>)
# </th>
# <th class="unsortable">
# </th></tr>
# <tr>
# <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –
# </td>
# <td><b><span class="flagicon" style="padding-left:25px;"> </span>World</b>
# </td>
# <td>8,087,686,000</td>
# <td><div class="center" style="width:auto; margin-left:auto; margin-right:auto;">100%</div></td>
# ...

# %%
rows = table.find_all("tr")

# %%
rows # th and td
# Out:
# [<tr>
#  <th>
#  </th>
#  <th style="width:17em"><a href="/wiki/List_of_sovereign_states" title="List of sovereign states">Country</a> / <a href="/wiki/Dependent_territory" title="Dependent territory">dependency</a>
#  </th>
#  <th>Population
#  </th>
#  <th style="width:2em">% of<br/>world
#  </th>
#  <th>Date
#  </th>
#  <th><span class="nowrap">Source (official or from</span><br/>the <a href="/wiki/United_Nations" title="United Nations">United Nations</a>)
#  </th>
#  <th class="unsortable">
#  </th></tr>,
#  <tr>
#  <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –
#  </td>
#  <td><b><span class="flagicon" style="padding-left:25px;"> </span>World</b>
#  </td>
#  <td>8,087,686,000</td>
#  <td><div class="center" style="width:auto; margin-left:auto; margin-right:auto;">100%</div></td>
#  <td><span data-sort-value="000000002024-02-06-0000" style="white-space:nowrap">6 Feb 2024</span>
#  </td>
# ...

# %%
for row in rows:
    th = row.find_all("th")
    print(th)
# Out:
# [<th>
# </th>, <th style="width:17em"><a href="/wiki/List_of_sovereign_states" title="List of sovereign states">Country</a> / <a href="/wiki/Dependent_territory" title="Dependent territory">dependency</a>
# </th>, <th>Population
# </th>, <th style="width:2em">% of<br/>world
# </th>, <th>Date
# </th>, <th><span class="nowrap">Source (official or from</span><br/>the <a href="/wiki/United_Nations" title="United Nations">United Nations</a>)
# </th>, <th class="unsortable">
# </th>]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
for row in rows:
    th_lst = row.find_all("th")
    for h in th_lst:
        print(h)
# Out:
# <th>
# </th>
# <th style="width:17em"><a href="/wiki/List_of_sovereign_states" title="List of sovereign states">Country</a> / <a href="/wiki/Dependent_territory" title="Dependent territory">dependency</a>
# </th>
# <th>Population
# </th>
# <th style="width:2em">% of<br/>world
# </th>
# <th>Date
# </th>
# <th><span class="nowrap">Source (official or from</span><br/>the <a href="/wiki/United_Nations" title="United Nations">United Nations</a>)
# </th>
# <th class="unsortable">
# </th>

# %%
for row in rows:
    th_lst = row.find_all("th")
    for h in th_lst:
        print(h.text)
# Out:
# Country / dependency
#
# Population
#
# % ofworld
#
# Date
#
# Source (official or fromthe United Nations)

# %%
for row in rows:
    th_lst = row.find_all("th")
    for h in th_lst:
        print(h.text.strip())
# Out:
# Country / dependency
# Population
# % ofworld
# Date
# Source (official or fromthe United Nations)

# %%
headers = []

for row in rows:
    th_lst = row.find_all("th")
    for h in th_lst:
        headers.append(h.text.strip())

# %%
print(headers)
# Out:
# ['', 'Country / dependency', 'Population', '% ofworld', 'Date', 'Source (official or fromthe United Nations)', '']

# %%
headers[0]
# Out:
# ''

# %%
headers[0] = "Rank"

# %%
headers
# Out:
# ['Rank',
#  'Country / dependency',
#  'Population',
#  '% ofworld',
#  'Date',
#  'Source (official or fromthe United Nations)',
#  '']

# %%
headers[-1]
# Out:
# ''

# %%
headers[-1] = "Notes"

# %%
headers
# Out:
# ['Rank',
#  'Country / dependency',
#  'Population',
#  '% ofworld',
#  'Date',
#  'Source (official or fromthe United Nations)',
#  'Notes']

# %%
for row in rows:
    td = row.find_all("td")
    print(td)
# Out:
# []
# [<td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –
# </td>, <td><b><span class="flagicon" style="padding-left:25px;"> </span>World</b>
# </td>, <td>8,087,686,000</td>, <td><div class="center" style="width:auto; margin-left:auto; margin-right:auto;">100%</div></td>, <td><span data-sort-value="000000002024-02-06-0000" style="white-space:nowrap">6 Feb 2024</span>
# </td>, <td>UN projection<sup class="reference" id="cite_ref-unpop_4-0"><a href="#cite_note-unpop-4">[3]</a></sup></td>, <td>
# </td>]
# [<td rowspan="2"><span data-sort-value="7000100000000000000♠" style="display:none"></span> 1/2 <br/> <sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[b]</a></sup>
# ...

# %%
for row in rows:
    td = row.find_all("td")
    for d in td:
        print(d)
# Out:
# <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –
# </td>
# <td><b><span class="flagicon" style="padding-left:25px;"> </span>World</b>
# </td>
# <td>8,087,686,000</td>
# <td><div class="center" style="width:auto; margin-left:auto; margin-right:auto;">100%</div></td>
# <td><span data-sort-value="000000002024-02-06-0000" style="white-space:nowrap">6 Feb 2024</span>
# </td>
# <td>UN projection<sup class="reference" id="cite_ref-unpop_4-0"><a href="#cite_note-unpop-4">[3]</a></sup></td>
# <td>
# </td>
# <td rowspan="2"><span data-sort-value="7000100000000000000♠" style="display:none"></span> 1/2 <br/> <sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[b]</a></sup>
# </td>
# ...

# %%
for row in rows:
    td = row.find_all("td")
    for d in td:
        print(d.text.strip())
# Out:
# –
# World
# 8,087,686,000
# 100%
# 6 Feb 2024
# UN projection[3]
#
# 1/2  [b]
# China
# 1,409,670,000
# 17.4%
# 31 Dec 2023
# Official estimate[5]
# [c]
# India
# 1,392,329,000
# 17.2%
# 1 Jul 2023
# Official projection[6]
# [d]
# 3
# United States
# 335,893,238
# 4.2%
# 1 Jan 2024
# Official estimate[7]
# [e]
# 4
# Indonesia
# 279,118,866
# 3.5%
# 1 Jul 2023
# National annual projection[8]
#
# 5
# Pakistan
# 241,499,431
# 3.0%
# 1 Mar 2023
# 2023 census result[9]
# [f]
# 6
# Nigeria
# 216,783,381
# 2.7%
# 1 Jul 2022
# Official projection[10]
#
# 7
# Brazil
# 203,080,756
# 2.5%
# 1 Aug 2022
# 2022 census result[11]
#
# 8
# Bangladesh
# 169,828,911
# 2.1%
# 14 Jun 2022
# 2022 census result[12]
#
# 9
# Russia
# 146,424,729
# 1.8%
# 1 Jan 2023
# Official estimate[13]
# [g]
# 10
# Mexico
# 129,406,736
# 1.6%
# 30 Sep 2023
# National quarterly estimate[14]
#
# 11
# Japan
# 124,090,000
# 1.5%
# 1 Jan 2024
# Official estimate[15]
#
# 12
# Philippines
# 112,892,781
# 1.4%
# 1 Jul 2023
# ...

# %%
for row in rows:
    td = row.find_all("td")
    table_data = []
    for d in td:
        table_data.append(d.text.strip())
    print(table_data)
# Out:
# []
# ['–', 'World', '8,087,686,000', '100%', '6 Feb 2024', 'UN projection[3]', '']
# ['1/2  [b]', 'China', '1,409,670,000', '17.4%', '31 Dec 2023', 'Official estimate[5]', '[c]']
# ['India', '1,392,329,000', '17.2%', '1 Jul 2023', 'Official projection[6]', '[d]']
# ['3', 'United States', '335,893,238', '4.2%', '1 Jan 2024', 'Official estimate[7]', '[e]']
# ['4', 'Indonesia', '279,118,866', '3.5%', '1 Jul 2023', 'National annual projection[8]', '']
# ['5', 'Pakistan', '241,499,431', '3.0%', '1 Mar 2023', '2023 census result[9]', '[f]']
# ['6', 'Nigeria', '216,783,381', '2.7%', '1 Jul 2022', 'Official projection[10]', '']
# ['7', 'Brazil', '203,080,756', '2.5%', '1 Aug 2022', '2022 census result[11]', '']
# ['8', 'Bangladesh', '169,828,911', '2.1%', '14 Jun 2022', '2022 census result[12]', '']
# ['9', 'Russia', '146,424,729', '1.8%', '1 Jan 2023', 'Official estimate[13]', '[g]']
# ['10', 'Mexico', '129,406,736', '1.6%', '30 Sep 2023', 'National quarterly estimate[14]', '']
# ...

# %%
final_data = []
for row in rows:
    td = row.find_all("td")
    table_data = []
    for d in td:
        table_data.append(d.text.strip())
    final_data.append(table_data)

# %%
final_data
# Out:
# [[],
#  ['–', 'World', '8,087,686,000', '100%', '6 Feb 2024', 'UN projection[3]', ''],
#  ['1/2  [b]',
#   'China',
#   '1,409,670,000',
#   '17.4%',
#   '31 Dec 2023',
#   'Official estimate[5]',
#   '[c]'],
#  ['India',
#   '1,392,329,000',
#   '17.2%',
#   '1 Jul 2023',
#   'Official projection[6]',
#   '[d]'],
#  ['3',
#   'United States',
#   '335,893,238',
#   '4.2%',
#   '1 Jan 2024',
#   'Official estimate[7]',
#   '[e]'],
#  ['4',
#   'Indonesia',
#   '279,118,866',
#   '3.5%',
#   '1 Jul 2023',
#   'National annual projection[8]',
#   ''],
#  ['5',
#   'Pakistan',
#   '241,499,431',
#   '3.0%',
#   '1 Mar 2023',
#   '2023 census result[9]',
#   '[f]'],
#  ['6',
#   'Nigeria',
#   '216,783,381',
#   '2.7%',
#   '1 Jul 2022',
#   'Official projection[10]',
#   ''],
#  ['7',
#   'Brazil',
#   '203,080,756',
#   '2.5%',
#   '1 Aug 2022',
#   '2022 census result[11]',
#   ''],
#  ['8',
#   'Bangladesh',
#   '169,828,911',
#   '2.1%',
#   '14 Jun 2022',
# ...

# %%
final_data = final_data[1:]

# %%
final_data[1]
# Out:
# ['1/2  [b]',
#  'China',
#  '1,409,670,000',
#  '17.4%',
#  '31 Dec 2023',
#  'Official estimate[5]',
#  '[c]']

# %%
final_data[1][0] = "1"

# %%
final_data
# Out:
# [['–', 'World', '8,087,686,000', '100%', '6 Feb 2024', 'UN projection[3]', ''],
#  ['1',
#   'China',
#   '1,409,670,000',
#   '17.4%',
#   '31 Dec 2023',
#   'Official estimate[5]',
#   '[c]'],
#  ['India',
#   '1,392,329,000',
#   '17.2%',
#   '1 Jul 2023',
#   'Official projection[6]',
#   '[d]'],
#  ['3',
#   'United States',
#   '335,893,238',
#   '4.2%',
#   '1 Jan 2024',
#   'Official estimate[7]',
#   '[e]'],
#  ['4',
#   'Indonesia',
#   '279,118,866',
#   '3.5%',
#   '1 Jul 2023',
#   'National annual projection[8]',
#   ''],
#  ['5',
#   'Pakistan',
#   '241,499,431',
#   '3.0%',
#   '1 Mar 2023',
#   '2023 census result[9]',
#   '[f]'],
#  ['6',
#   'Nigeria',
#   '216,783,381',
#   '2.7%',
#   '1 Jul 2022',
#   'Official projection[10]',
#   ''],
#  ['7',
#   'Brazil',
#   '203,080,756',
#   '2.5%',
#   '1 Aug 2022',
#   '2022 census result[11]',
#   ''],
#  ['8',
#   'Bangladesh',
#   '169,828,911',
#   '2.1%',
#   '14 Jun 2022',
#   '2022 census result[12]',
#   ''],
# ...

# %%
final_data[2].insert(0,"2")

# %%
final_data
# Out:
# [['–', 'World', '8,087,686,000', '100%', '6 Feb 2024', 'UN projection[3]', ''],
#  ['1',
#   'China',
#   '1,409,670,000',
#   '17.4%',
#   '31 Dec 2023',
#   'Official estimate[5]',
#   '[c]'],
#  ['2',
#   'India',
#   '1,392,329,000',
#   '17.2%',
#   '1 Jul 2023',
#   'Official projection[6]',
#   '[d]'],
#  ['3',
#   'United States',
#   '335,893,238',
#   '4.2%',
#   '1 Jan 2024',
#   'Official estimate[7]',
#   '[e]'],
#  ['4',
#   'Indonesia',
#   '279,118,866',
#   '3.5%',
#   '1 Jul 2023',
#   'National annual projection[8]',
#   ''],
#  ['5',
#   'Pakistan',
#   '241,499,431',
#   '3.0%',
#   '1 Mar 2023',
#   '2023 census result[9]',
#   '[f]'],
#  ['6',
#   'Nigeria',
#   '216,783,381',
#   '2.7%',
#   '1 Jul 2022',
#   'Official projection[10]',
#   ''],
#  ['7',
#   'Brazil',
#   '203,080,756',
#   '2.5%',
#   '1 Aug 2022',
#   '2022 census result[11]',
#   ''],
#  ['8',
#   'Bangladesh',
#   '169,828,911',
#   '2.1%',
#   '14 Jun 2022',
#   '2022 census result[12]',
# ...

# %%
import pandas as pd

# %%
pop = pd.DataFrame(final_data)

# %%
pop
# Out:
#        0                                    1              2      3  \
# 0      –                                World  8,087,686,000   100%
# 1      1                                China  1,409,670,000  17.4%
# 2      2                                India  1,392,329,000  17.2%
# 3      3                        United States    335,893,238   4.2%
# 4      4                            Indonesia    279,118,866   3.5%
# ..   ...                                  ...            ...    ...
# 236    –                            Niue (NZ)          1,689     0%
# 237    –                         Tokelau (NZ)          1,647     0%
# 238  195                         Vatican City            764     0%
# 239    –  Cocos (Keeling) Islands (Australia)            593     0%
# 240    –                Pitcairn Islands (UK)             47     0%
#
#                4                              5     6
# 0     6 Feb 2024               UN projection[3]
# ...

# %%
pop.columns
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
pop.columns = headers

# %%
pop
# Out:
#     Rank                 Country / dependency     Population % ofworld  \
# 0      –                                World  8,087,686,000      100%
# 1      1                                China  1,409,670,000     17.4%
# 2      2                                India  1,392,329,000     17.2%
# 3      3                        United States    335,893,238      4.2%
# 4      4                            Indonesia    279,118,866      3.5%
# ..   ...                                  ...            ...       ...
# 236    –                            Niue (NZ)          1,689        0%
# 237    –                         Tokelau (NZ)          1,647        0%
# 238  195                         Vatican City            764        0%
# 239    –  Cocos (Keeling) Islands (Australia)            593        0%
# 240    –                Pitcairn Islands (UK)             47        0%
#
#             Date Source (official or fromthe United Nations) Notes
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Rank                                         241 non-null    object
#  1   Country / dependency                         241 non-null    object
#  2   Population                                   241 non-null    object
#  3   % ofworld                                    241 non-null    object
#  4   Date                                         241 non-null    object
#  5   Source (official or fromthe United Nations)  241 non-null    object
#  6   Notes                                        241 non-null    object
# dtypes: object(7)
# memory usage: 13.3+ KB

# %%
pop["% ofworld"]
# Out:
# 0       100%
# 1      17.4%
# 2      17.2%
# 3       4.2%
# 4       3.5%
#        ...
# 236       0%
# 237       0%
# 238       0%
# 239       0%
# 240       0%
# Name: % ofworld, Length: 241, dtype: object

# %%
pop["% ofworld"] = pop["% ofworld"].str.strip("%").astype(float)

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Rank                                         241 non-null    object
#  1   Country / dependency                         241 non-null    object
#  2   Population                                   241 non-null    object
#  3   % ofworld                                    241 non-null    float64
#  4   Date                                         241 non-null    object
#  5   Source (official or fromthe United Nations)  241 non-null    object
#  6   Notes                                        241 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 13.3+ KB

# %%
pop["Population"].str.replace(",","")
# Out:
# 0      8087686000
# 1      1409670000
# 2      1392329000
# 3       335893238
# 4       279118866
#           ...
# 236          1689
# 237          1647
# 238           764
# 239           593
# 240            47
# Name: Population, Length: 241, dtype: object

# %%
pop["Population"] = pop["Population"].str.replace(",","")

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Rank                                         241 non-null    object
#  1   Country / dependency                         241 non-null    object
#  2   Population                                   241 non-null    object
#  3   % ofworld                                    241 non-null    float64
#  4   Date                                         241 non-null    object
#  5   Source (official or fromthe United Nations)  241 non-null    object
#  6   Notes                                        241 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 13.3+ KB

# %%
pop["Population"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 pop["Population"].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
# ...

# %%
popul = []


for i in pop["Population"]:
    p = int(i)
    popul.append(p)

# %%
pop["Population"] = popul

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Rank                                         241 non-null    object
#  1   Country / dependency                         241 non-null    object
#  2   Population                                   241 non-null    int64
#  3   % ofworld                                    241 non-null    float64
#  4   Date                                         241 non-null    object
#  5   Source (official or fromthe United Nations)  241 non-null    object
#  6   Notes                                        241 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 13.3+ KB

# %%
import datetime as dt

# %%
pop["Date"].head(59)
# Out:
# 0      6 Feb 2024
# 1     31 Dec 2023
# 2      1 Jul 2023
# 3      1 Jan 2024
# 4      1 Jul 2023
# 5      1 Mar 2023
# 6      1 Jul 2022
# 7      1 Aug 2022
# 8     14 Jun 2022
# 9      1 Jan 2023
# 10    30 Sep 2023
# 11     1 Jan 2024
# 12     1 Jul 2023
# 13     1 Jul 2023
# 14     1 Jan 2023
# 15       Jul 2023
# 16     1 Jul 2019
# 17    31 Dec 2023
# 18    30 Sep 2023
# 19     1 Jan 2021
# 20     1 Jan 2024
# 21     1 Jul 2021
# 22    30 Jun 2021
# 23     2 Feb 2022
# 24    23 Aug 2022
# 25    31 Oct 2023
# 26     1 Jul 2022
# 27    30 Jun 2023
# 28     1 Jan 2023
# 29    31 Dec 2022
# 30     1 Oct 2023
# 31     1 Jul 2023
# 32     1 Jul 2023
# 33     1 Jan 2022
# 34     1 Jul 2023
# 35     1 Jul 2018
# 36     1 Oct 2023
# 37    31 Oct 2023
# 38     1 Jul 2023
# 39           2023
# 40     1 Oct 2023
# 41     1 Jan 2023
# 42     1 Jun 2023
# 43     1 Jul 2022
# 44    30 Jun 2023
# 45     1 Jul 2022
# 46    10 May 2022
# 47     1 Jul 2022
# 48    27 Jun 2021
# 49    14 Dec 2021
# ...

# %%
pd.to_datetime(pop["Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 pd.to_datetime(pop["Date"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# ...

# %%
date = "1 Oct 2023"
date_format = "%d %b %Y"

# %%
dt.datetime.strptime("1 Oct 2023", "%d %b %Y")
# Out:
# datetime.datetime(2023, 10, 1, 0, 0)

# %%
dt.datetime.strptime("Oct 2023", "%b %Y")
# Out:
# datetime.datetime(2023, 10, 1, 0, 0)

# %%
dt.datetime.strptime("2023", "%Y")
# Out:
# datetime.datetime(2023, 1, 1, 0, 0)

# %%
len("12 Oct 2023")
len("1 Oct 2023")
# Out:
# 10

# %%
def conv_date(date):
    if len(date) < 10:
        try:
            date = dt.datetime.strptime(date, "%b %Y")
        except:
            date = dt.datetime.strptime(date, "%Y")
    else:
        date = dt.datetime.strptime(date, "%d %b %Y")
        
    return date

# %%
pop
# Out:
#     Rank                 Country / dependency  Population  % ofworld  \
# 0      –                                World  8087686000      100.0
# 1      1                                China  1409670000       17.4
# 2      2                                India  1392329000       17.2
# 3      3                        United States   335893238        4.2
# 4      4                            Indonesia   279118866        3.5
# ..   ...                                  ...         ...        ...
# 236    –                            Niue (NZ)        1689        0.0
# 237    –                         Tokelau (NZ)        1647        0.0
# 238  195                         Vatican City         764        0.0
# 239    –  Cocos (Keeling) Islands (Australia)         593        0.0
# 240    –                Pitcairn Islands (UK)          47        0.0
#
#             Date Source (official or fromthe United Nations) Notes
# 0     6 Feb 2024                            UN projection[3]
# ...

# %%
pop["Date"].apply(conv_date)
# Out:
# 0     2024-02-06
# 1     2023-12-31
# 2     2023-07-01
# 3     2024-01-01
# 4     2023-07-01
#          ...
# 236   2022-11-11
# 237   2019-01-01
# 238   2023-06-26
# 239   2020-06-30
# 240   2021-07-01
# Name: Date, Length: 241, dtype: datetime64[ns]

# %%
pop["Date"] = pop["Date"].apply(conv_date)

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Rank                                         241 non-null    object
#  1   Country / dependency                         241 non-null    object
#  2   Population                                   241 non-null    int64
#  3   % ofworld                                    241 non-null    float64
#  4   Date                                         241 non-null    datetime64[ns]
#  5   Source (official or fromthe United Nations)  241 non-null    object
#  6   Notes                                        241 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 13.3+ KB

# %%
pop.to_csv("population.csv", index = False)
