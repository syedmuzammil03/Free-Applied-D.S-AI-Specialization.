# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
file = "modern_arts.csv"

arts = pd.read_csv(file)

# %%
arts
# Out:
#                                                    Title              Artist
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth  \
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
arts.shape
# Out:
# (16725, 8)

# %%
num_rows = arts.shape[0]
# Out:
# 16725

# %%
type(arts) # 2 dimension
# Out:
# pandas.core.frame.DataFrame

# %%
arts.columns
# Out:
# Index(['Title', 'Artist', 'Nationality', 'BeginDate', 'EndDate', 'Gender',
#        'Date', 'Department'],
#       dtype='object')

# %%
arts.head()
# Out:
#                                                Title              Artist
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth  \
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality BeginDate EndDate    Gender       Date
# 0  (American)    (1947)  (2013)  (Female)       1986  \
# 1   (Spanish)    (1916)  (2007)    (Male)       1978
# 2    (French)    (1870)  (1943)    (Male)  1889-1911
# 3    (French)    (1861)  (1944)    (Male)  1927-1940
# 4    (French)    (1857)  (1927)    (Male)       1903
#
#                    Department
# 0  Prints & Illustrated Books
# 1  Prints & Illustrated Books
# 2  Prints & Illustrated Books
# 3  Prints & Illustrated Books
# 4                 Photography

# %%
arts.head(10)
# Out:
#                                                Title              Artist
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth  \
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
# 5        Pictorial ornament (folio 11) from WOODCUTS    Antonio Frasconi
# 6                            Rue de l'Hôtel-de-Ville        Eugène Atget
# 7                                Los Angeles Airport     Garry Winogrand
# 8                   Why Defy from Disasters of Peace        Diane Victor
# 9                               STILL WATER AND FISH   David Brown Milne
#
#        Nationality BeginDate EndDate    Gender       Date
# 0       (American)    (1947)  (2013)  (Female)       1986  \
# ...

# %%
arts["Gender"] # 1 Dimension
# Out:
# 0        (Female)
# 1          (Male)
# 2          (Male)
# 3          (Male)
# 4          (Male)
#            ...
# 16720      (Male)
# 16721      (Male)
# 16722      (Male)
# 16723          ()
# 16724      (Male)
# Name: Gender, Length: 16725, dtype: object

# %%
type(arts["Gender"])
# Out:
# pandas.core.series.Series

# %%
cols = ["Artist", "Date"]


arts[cols]
# Out:
#                    Artist       Date
# 0      Sarah Charlesworth       1986
# 1         Pablo Palazuelo       1978
# 2           Maurice Denis  1889-1911
# 3        Aristide Maillol  1927-1940
# 4            Eugène Atget       1903
# ...                   ...        ...
# 16720         Henry Moore  1968-1969
# 16721         Juan Baixas       1975
# 16722       Edward Hopper       1922
# 16723             Unknown       1931
# 16724           Alex Katz       2011
#
# [16725 rows x 2 columns]

# %%
arts[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
arts.head(2)
# Out:
#                                                Title              Artist
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth  \
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
#
#   Nationality BeginDate EndDate    Gender  Date                  Department
# 0  (American)    (1947)  (2013)  (Female)  1986  Prints & Illustrated Books
# 1   (Spanish)    (1916)  (2007)    (Male)  1978  Prints & Illustrated Books

# %%
arts.iloc[0]
# Out:
# Title          Dress MacLeod from Tartan Sets
# Artist                     Sarah Charlesworth
# Nationality                        (American)
# BeginDate                              (1947)
# EndDate                                (2013)
# Gender                               (Female)
# Date                                     1986
# Department         Prints & Illustrated Books
# Name: 0, dtype: object

# %%
arts.iloc[[0,4]]
# Out:
#                             Title              Artist Nationality BeginDate
# 0  Dress MacLeod from Tartan Sets  Sarah Charlesworth  (American)    (1947)  \
# 4                   97 rue du Bac        Eugène Atget    (French)    (1857)
#
#   EndDate    Gender  Date                  Department
# 0  (2013)  (Female)  1986  Prints & Illustrated Books
# 4  (1927)    (Male)  1903                 Photography

# %%
arts =arts.set_index("Nationality")

# %%
arts
# Out:
#                                                          Title
# Nationality
# (American)                      Dress MacLeod from Tartan Sets  \
# (Spanish)    Duplicate of plate from folio 11 verso (supple...
# (French)                      Tailpiece (page 55) from SAGESSE
# (French)     Headpiece (page 129) from LIVRET DE FOLASTRIES...
# (French)                                         97 rue du Bac
# ...                                                        ...
# (British)                                     Oval with Points
# (Chilean)      Cementerio de la Ciudad Abierta, Ritoque, Chile
# (American)                                         The Catboat
# ()           Dognat' i peregnat' v tekhniko-ekonomicheskom ...
# (American)                       Plate (page 11) from The Dive
#
#                          Artist BeginDate EndDate    Gender       Date
# Nationality
# (American)   Sarah Charlesworth    (1947)  (2013)  (Female)       1986  \
# ...

# %%
arts.columns
# Out:
# Index(['Title', 'Artist', 'BeginDate', 'EndDate', 'Gender', 'Date',
#        'Department'],
#       dtype='object')

# %%
arts
# Out:
#                                                          Title
# Nationality
# (American)                      Dress MacLeod from Tartan Sets  \
# (Spanish)    Duplicate of plate from folio 11 verso (supple...
# (French)                      Tailpiece (page 55) from SAGESSE
# (French)     Headpiece (page 129) from LIVRET DE FOLASTRIES...
# (French)                                         97 rue du Bac
# ...                                                        ...
# (British)                                     Oval with Points
# (Chilean)      Cementerio de la Ciudad Abierta, Ritoque, Chile
# (American)                                         The Catboat
# ()           Dognat' i peregnat' v tekhniko-ekonomicheskom ...
# (American)                       Plate (page 11) from The Dive
#
#                          Artist BeginDate EndDate    Gender       Date
# Nationality
# (American)   Sarah Charlesworth    (1947)  (2013)  (Female)       1986  \
# ...

# %%
arts.iloc[[0,2]]
# Out:
#                                         Title              Artist BeginDate
# Nationality
# (American)     Dress MacLeod from Tartan Sets  Sarah Charlesworth    (1947)  \
# (French)     Tailpiece (page 55) from SAGESSE       Maurice Denis    (1870)
#
#             EndDate    Gender       Date                  Department
# Nationality
# (American)   (2013)  (Female)       1986  Prints & Illustrated Books
# (French)     (1943)    (Male)  1889-1911  Prints & Illustrated Books

# %%
arts.loc[["(American)", "(Spanish)"]]
# Out:
#                                                          Title
# Nationality
# (American)                      Dress MacLeod from Tartan Sets  \
# (American)         Pictorial ornament (folio 11) from WOODCUTS
# (American)                                 Los Angeles Airport
# (American)                                      Black Bathroom
# (American)               Transcendence. Designs for the Ballet
# ...                                                        ...
# (Spanish)    S.O.S. Smoke Signals from Underground (SOS. Se...
# (Spanish)                             Montserrat Crying, No. 2
# (Spanish)    A bad night (Mala noche) (plate 36, folio 36) ...
# (Spanish)    And his house is on fire (Y sele quema la casa...
# (Spanish)                                  Two Figures, Seated
#
#                                 Artist BeginDate EndDate    Gender       Date
# Nationality
# (American)          Sarah Charlesworth    (1947)  (2013)  (Female)       1986  \
# ...

# %%
arts.iloc[[0,4]]
# Out:
#                                       Title              Artist BeginDate
# Nationality
# (American)   Dress MacLeod from Tartan Sets  Sarah Charlesworth    (1947)  \
# (French)                      97 rue du Bac        Eugène Atget    (1857)
#
#             EndDate    Gender  Date                  Department
# Nationality
# (American)   (2013)  (Female)  1986  Prints & Illustrated Books
# (French)     (1927)    (Male)  1903                 Photography

# %%
arts.iloc[[0,4],5]
# Out:
# Nationality
# (American)    1986
# (French)      1903
# Name: Date, dtype: object

# %%
arts.iloc[[0,4],[0,3]]
# Out:
#                                       Title EndDate
# Nationality
# (American)   Dress MacLeod from Tartan Sets  (2013)
# (French)                      97 rue du Bac  (1927)

# %%
arts.loc[["(American)", "(Spanish)"],[0,3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 arts.loc[["(American)", "(Spanish)"],[0,3]]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1287, in _LocIndexer._getitem_tuple(self, tup)
#    1285 # ugly hack for GH #836
#    1286 if self._multi_take_opportunity(tup):
# -> 1287     return self._multi_take(tup)
#    1289 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
arts.loc[["(American)", "(Spanish)"],["Date","Gender"]]
# Out:
#                   Date    Gender
# Nationality
# (American)        1986  (Female)
# (American)        1957    (Male)
# (American)   1978-1983    (Male)
# (American)        1963    (Male)
# (American)      (1934)    (Male)
# ...                ...       ...
# (Spanish)         2016    (Male)
# (Spanish)         1938    (Male)
# (Spanish)    1797-1799    (Male)
# (Spanish)    1797-1799    (Male)
# (Spanish)      c. 1920    (Male)
#
# [7787 rows x 2 columns]

# %%
arts.tail(7)
# Out:
#                                                          Title
# Nationality
# (American)                                           High Peak  \
# (French)                      Picasso Sculpture (paper, skull)
# (British)                                     Oval with Points
# (Chilean)      Cementerio de la Ciudad Abierta, Ritoque, Chile
# (American)                                         The Catboat
# ()           Dognat' i peregnat' v tekhniko-ekonomicheskom ...
# (American)                       Plate (page 11) from The Dive
#
#                              Artist BeginDate EndDate  Gender       Date
# Nationality
# (American)   Matthew Rackham Barnes    (1880)  (1951)  (Male)       1936  \
# (French)     Brassaï (Gyula Halász)    (1899)  (1984)  (Male)       1943
# (British)               Henry Moore    (1898)  (1986)  (Male)  1968-1969
# (Chilean)               Juan Baixas    (1942)     NaN  (Male)       1975
# ...
