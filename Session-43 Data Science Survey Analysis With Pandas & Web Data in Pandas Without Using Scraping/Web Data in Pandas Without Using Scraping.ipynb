# %%
url = "https://en.wikipedia.org/wiki/List_of_helicopter_prison_escapes"

# %%
import pandas as pd

# %%
data = pd.read_html(url)

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 8

# %%
data[0]
# Out:
#     0                                                  1
# 0 NaN  This list is incomplete; you can help by addin...

# %%
actual_attempts = data[1]

# %%
actual_attempts.head()
# Out:
#                 Date                                   Prison name  \
# 0    August 19, 1971                         Santa Martha Acatitla
# 1   October 31, 1973                         Mountjoy Jail, Dublin
# 2       May 24, 1978  United States Penitentiary, Marion, Illinois
# 3  February 27, 1981        Fleury-Mérogis, Essonne, Ile de France
# 4        May 7, 1981               Orsainville Prison, Quebec City
#
#          Country Succeeded                                         Escapee(s)  \
# 0         Mexico       Yes  Joel David Kaplan Carlos Antonio Contreras Castro
# 1        Ireland       Yes              JB O'Hagan Seamus Twomey Kevin Mallon
# 2  United States        No  Garrett Brock Trapnell Martin Joseph McNally J...
# 3         France       Yes                       Gérard Dupré Daniel Beaumont
# 4         Canada        No  Marina Paquet (hijacker) Giles Arseneault (pri...
#
#                                              Details
# ...

# %%
actual_attempts["Date"].str[-4:].astype(int)
# Out:
# 0     1971
# 1     1973
# 2     1978
# 3     1981
# 4     1981
# 5     1983
# 6     1985
# 7     1985
# 8     1986
# 9     1986
# 10    1986
# 11    1987
# 12    1988
# 13    1989
# 14    1989
# 15    1990
# 16    1991
# 17    1992
# 18    1992
# 19    1993
# 20    1996
# 21    1997
# 22    1999
# 23    2000
# 24    2000
# 25    2001
# 26    2001
# 27    2001
# 28    2002
# 29    2002
# 30    2003
# 31    2005
# 32    2005
# 33    2006
# 34    2007
# 35    2007
# 36    2007
# 37    2009
# 38    2009
# 39    2009
# 40    2010
# 41    2012
# 42    2013
# 43    2013
# 44    2014
# 45    2016
# 46    2018
# 47    2020
# Name: Date, dtype: int32

# %%
actual_attempts["Year"] = actual_attempts["Date"].str[-4:].astype(int)

# %%
actual_attempts
# Out:
#                   Date                                        Prison name  \
# 0      August 19, 1971                              Santa Martha Acatitla
# 1     October 31, 1973                              Mountjoy Jail, Dublin
# 2         May 24, 1978       United States Penitentiary, Marion, Illinois
# 3    February 27, 1981             Fleury-Mérogis, Essonne, Ile de France
# 4          May 7, 1981                    Orsainville Prison, Quebec City
# 5        January, 1983                              Pentridge (HM Prison)
# 6    December 19, 1985  Perry Correctional Institution, Pelzer, South ...
# 7    December 31, 1985  Cândido Mendes penitentiary, Ilha Grande, Rio ...
# 8         May 26, 1986                                 Prison de la Santé
# 9     November 5, 1986  Federal Correctional Institution, Dublin, Cali...
# 10   November 23, 1986                         Prigione di Rebibbia, Rome
# 11   December 10, 1987                                Gartree (HM Prison)
# ...

# %%
yearly_attempts = actual_attempts["Year"].value_counts()

# %%
actual_attempts["Country"].value_counts()
# Out:
# Country
# France            15
# United States      8
# Canada             4
# Greece             4
# Belgium            4
# Australia          2
# Brazil             2
# United Kingdom     2
# Mexico             1
# Ireland            1
# Italy              1
# Puerto Rico        1
# Chile              1
# Netherlands        1
# Russia             1
# Name: count, dtype: int64
